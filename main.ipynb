# %% [markdown]
# Pyramid Patterns

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(5):
    for i in range(i+1):
        print("*", end="")
    print("")
# Out:
# *
# **
# ***
# ****
# *****
